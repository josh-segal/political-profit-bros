# %%
import json
import requests
import pandas as pd
from datetime import datetime
from collections import Counter


stock_ticker = 'GLEN'
key = '&apikey=j479N8NO7P5sw8YI1X0srvkDDWGQPODS'
real_url = f'https://financialmodelingprep.com/api/v3/search?query={stock_ticker}{key}'
response = requests.get(real_url)
data = response.json()


data
# Out:
# [{'symbol': 'GLEN.L',
#   'name': 'Glencore plc',
#   'currency': 'GBp',
#   'stockExchange': 'London Stock Exchange',
#   'exchangeShortName': 'LSE'},
#  {'symbol': 'GLENMARK.NS',
#   'name': 'Glenmark Pharmaceuticals Limited',
#   'currency': 'INR',
#   'stockExchange': 'National Stock Exchange of India',
#   'exchangeShortName': 'NSE'},
#  {'symbol': 'GLENMARK.BO',
#   'name': 'Glenmark Pharmaceuticals Limited',
#   'currency': 'INR',
#   'stockExchange': 'Bombay Stock Exchange',
#   'exchangeShortName': 'BSE'},
#  {'symbol': 'GLNCY',
#   'name': 'Glencore plc',
#   'currency': 'USD',
#   'stockExchange': 'Other OTC',
#   'exchangeShortName': 'PNK'},
#  {'symbol': 'GLCNF',
#   'name': 'Glencore plc',
#   'currency': 'USD',
#   'stockExchange': 'Other OTC',
#   'exchangeShortName': 'PNK'},
#  {'symbol': 'GLBZ',
#   'name': 'Glen Burnie Bancorp',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GGMCW',
#   'name': 'Glenfarne Merger Corp.',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GGMCU',
#   'name': 'Glenfarne Merger Corp.',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GGMC',
#   'name': 'Glenfarne Merger Corp.',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GVR.IR',
#   'name': 'Glenveagh Properties PLC',
#   'currency': 'EUR',
#   'stockExchange': 'Irish',
#   'exchangeShortName': 'EURONEXT'},
#  {'symbol': 'GLV.L',
#   'name': 'Glenveagh Properties PLC',
#   'currency': 'EUR',
#   'stockExchange': 'London Stock Exchange',
#   'exchangeShortName': 'LSE'},
#  {'symbol': 'GLVHF',
#   'name': 'Glenveagh Properties PLC',
#   'currency': 'USD',
#   'stockExchange': 'Other OTC',
#   'exchangeShortName': 'PNK'},
#  {'symbol': 'GER.V',
#   'name': 'Glen Eagle Resources Inc.',
#   'currency': 'CAD',
#   'stockExchange': 'Toronto Stock Exchange Ventures',
#   'exchangeShortName': 'TSXV'},
#  {'symbol': 'GERFF',
#   'name': 'Glen Eagle Resources Inc.',
#   'currency': 'USD',
#   'stockExchange': 'Other OTC',
#   'exchangeShortName': 'PNK'},
#  {'symbol': 'GC1.AX',
#   'name': 'Glennon Small Companies Ltd',
#   'currency': 'AUD',
#   'stockExchange': 'Australian Securities Exchange',
#   'exchangeShortName': 'ASX'},
#  {'symbol': 'GTLLX',
#   'name': 'Glenmede Large Cap Growth Ptf',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GTAPX',
#   'name': 'Glenmede Long/Short Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GLS.NS',
#   'name': 'Glenmark Life Sciences Limited',
#   'currency': 'INR',
#   'stockExchange': 'National Stock Exchange of India',
#   'exchangeShortName': 'NSE'},
#  {'symbol': 'GLS.BO',
#   'name': 'Glenmark Life Sciences Limited',
#   'currency': 'INR',
#   'stockExchange': 'Bombay Stock Exchange',
#   'exchangeShortName': 'BSE'},
#  {'symbol': 'GTTMX',
#   'name': 'Glenmede Total Market Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GLRP',
#   'name': 'Glen Rose Petroleum Corporation',
#   'currency': 'USD',
#   'stockExchange': 'Other OTC',
#   'exchangeShortName': 'PNK'},
#  {'symbol': 'GTSOX',
#   'name': 'Glenmede Secured Options Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GTSCX',
#   'name': 'Glenmede Small Cap Equity Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GTCEX',
#   'name': 'Glenmede Strategic Equity Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GLNV',
#   'name': 'Glenville Bank Holding Company, Inc.',
#   'currency': 'USD',
#   'stockExchange': 'Other OTC',
#   'exchangeShortName': 'PNK'},
#  {'symbol': 'GTCIX',
#   'name': 'Glenmede Fund International Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GTCGX',
#   'name': 'Glenmede Fund Core Fixed Income Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GTCSX',
#   'name': 'Glenmede Small Cap Equity Portfolio Class Advisor',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GTLOX',
#   'name': 'Glenmede Quantitative U.S. Large Cap Core Equity Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': 'GTLIX',
#   'name': 'Glenmede Quantitative U.S. Large Cap Core Equity Portfolio',
#   'currency': 'USD',
#   'stockExchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ'},
#  {'symbol': '2931.T',
#   'name': 'Euglena Co., Ltd.',
#   'currency': 'JPY',
#   'stockExchange': 'Tokyo',
#   'exchangeShortName': 'JPX'},
#  {'symbol': '688112.SS',
#   'name': 'Siglent Technologies CO., Ltd.',
#   'currency': 'CNY',
#   'stockExchange': 'Shanghai',
#   'exchangeShortName': 'SHH'},
#  {'symbol': 'NDIGLENHKL1.CO',
#   'name': 'Investeringsforeningen Nordea Invest - Global Enhanced',
#   'currency': 'DKK',
#   'stockExchange': 'Copenhagen',
#   'exchangeShortName': 'CPH'},
#  {'symbol': '0008.KL',
#   'name': 'Willowglen MSC Berhad',
#   'currency': 'MYR',
#   'stockExchange': 'Kuala Lumpur',
#   'exchangeShortName': 'KLS'},
#  {'symbol': '3LGL.L',
#   'name': 'GraniteShares 3x Long Glencore Daily ETC',
#   'currency': 'GBp',
#   'stockExchange': 'London Stock Exchange',
#   'exchangeShortName': 'LSE'}]

# %%
import re


names = soup.find_all(class_='q-fieldset politician-name')
name_lst = [name.text for name in names]

party_pattern = re.compile(r'q-field party party--')
parties = soup.find_all(class_=party_pattern)
party_lst = [party.text for party in parties]

chamber_pattern = re.compile(r'q-field chamber chamber--')
chambers = soup.find_all(class_=chamber_pattern)
chamber_lst = [chamber.text for chamber in chambers]

state_pattern = re.compile(r'q-field us-state-compact us-state-compact--')
states = soup.find_all(class_=state_pattern)
state_lst = [state.text for state in states]

issuers = soup.find_all(class_='q-fieldset issuer-name')
issuer_lst = [issue.text for issue in issuers]

issuers_ticker = soup.find_all(class_='q-field issuer-ticker')
issuer_ticker_lst = [ticker.text for ticker in issuers_ticker]


type_pattern = re.compile(r'q-field tx-type tx-type--')
types = soup.find_all(class_=type_pattern)
type_lst = [typee.text.capitalize() for typee in types]

"""
date_lst = []
dates = soup.find_all(class_='q-cell cell--count-issuers flavour--lv')
for date in dates:
    years = date.find_all(class_='q-label')
    days_months = date.find_all(class_='q-value')
    for year, day_month in zip(years, days_months):
        if year.text != 'Issuers': 
            #print(f'{year.text}{day_month.text}')
            date_object = datetime.strptime(f'{year.text}{day_month.text}', "%Y %d %b")
            date_lst.append(datetime(year=date_object.year, month=date_object.month, day=date_object.day))
"""                  
trade_prices = soup.find_all(class_='q-cell cell--trade-price')
#for price in trade_prices:
    
print(trade_prices)
#trade_prices_lst = [price.text for price in trade_prices]


df = pd.DataFrame({
    'Name': politician_name_lst,
    'Party': politician_party_lst,
    'Chamber': chamber_lst,
    'State': state_lst,
    'Issuer': issuer_lst,
    'Ticker': issuer_ticker_lst,
    'Type': type_lst
    #'Published': date_lst[::2],
    #'Traded': date_lst[1::2]
        
    }
)

df

# %% [markdown]
# ### Web Scraping Politicians

# %%
from bs4 import BeautifulSoup
url = 'https://bff.capitoltrades.com/trades?per_page=96&page=3&pageSize=96'
json_try = requests.get(url)
dict_json = json.loads(json_try.text)

# %%
dict_json['data'][0]
# Out:
# {'_txId': 20003773481,
#  '_politicianId': 'M001157',
#  '_assetId': 100005342,
#  '_issuerId': 430093,
#  'pubDate': '2024-05-21T13:05:05Z',
#  'filingDate': '2024-05-17',
#  'txDate': '2024-04-22',
#  'txType': 'buy',
#  'txTypeExtended': None,
#  'hasCapitalGains': False,
#  'owner': 'child',
#  'chamber': 'house',
#  'price': 74.02,
#  'size': 440,
#  'sizeRangeHigh': 676,
#  'sizeRangeLow': 203,
#  'value': 32500,
#  'filingId': 204852136,
#  'filingURL': 'https://disclosures-clerk.house.gov/public_disc/ptr-pdfs/2024/8220320.pdf',
#  'reportingGap': 25,
#  'comment': None,
#  'committees': ['hsfa', 'hshm'],
#  'asset': {'assetType': 'stock', 'assetTicker': 'BJ:US', 'instrument': None},
#  'issuer': {'_stateId': 'ma',
#   'c2iq': 'LGZVU1C8',
#   'country': 'us',
#   'issuerName': "BJ's Wholesale Club Holdings Inc",
#   'issuerTicker': 'BJ:US',
#   'sector': 'consumer-staples'},
#  'politician': {'_stateId': 'tx',
#   'chamber': 'house',
#   'dob': '1962-01-14',
#   'firstName': 'Michael',
#   'gender': 'male',
#   'lastName': 'McCaul',
#   'nickname': None,
#   'party': 'republican'},
#  'labels': []}

# %%
name_lst = [index['politician']['firstName'] + " " + index['politician']['lastName'] for index in dict_json['data']]
id_lst = [index['_politicianId'] for index in dict_json['data']]
party_lst = [index['politician']['party'].capitalize() for index in dict_json['data']]
chamber_lst = [index['politician']['chamber'].capitalize() for index in dict_json['data']]
state_lst = [index['politician']['_stateId'].upper() for index in dict_json['data']]
asset_type_lst = [index['asset']['assetType'].capitalize() for index in dict_json['data']]
issuer_lst = [index['issuer']['issuerName'] for index in dict_json['data']]
issuer_ticker_lst = []
for index in dict_json['data']:
    if index['issuer']['issuerTicker'] is not None:
        issuer_ticker_lst.append(index['issuer']['issuerTicker'].split(':')[0])
    else:
        issuer_ticker_lst.append(None)

issuer_country_lst = [index['issuer']['country'] for index in dict_json['data']]
type_lst = [index['txType'].capitalize() for index in dict_json['data']]

date_lst = []
for index in dict_json['data']:
    date_object = datetime.strptime(index['txDate'], '%Y-%m-%d')
    date_lst.append(date_object)

trade_size_lst = [index['size'] for index in dict_json['data']]
trade_price = [index['price'] for index in dict_json['data']]
trade_value = [index['value'] for index in dict_json['data']]

# %%
df = pd.DataFrame({
    'Name': name_lst,
    'Politician Id': id_lst,
    'Party': party_lst,
    'Chamber': chamber_lst,
    'State': state_lst,
    'Asset Type': asset_type_lst,
    'Issuer': issuer_lst,
    'Ticker': issuer_ticker_lst,
    'Issuer Country': issuer_country_lst,
    'Type': type_lst,
    'Date': date_lst,
    'Trade Size': trade_size_lst,
    'Trade Price': trade_price,
    'Trade Value': trade_value
}
)

df
# Out:
#                    Name Politician Id       Party Chamber State  \
# 0        Michael McCaul       M001157  Republican   House    TX
# 1        Michael McCaul       M001157  Republican   House    TX
# 2        Michael McCaul       M001157  Republican   House    TX
# 3        Michael McCaul       M001157  Republican   House    TX
# 4        Michael McCaul       M001157  Republican   House    TX
# ..                  ...           ...         ...     ...   ...
# 91  Charles Fleischmann       F000459  Republican   House    TN
# 92      Deborah Dingell       D000624    Democrat   House    MI
# 93      Deborah Dingell       D000624    Democrat   House    MI
# 94        Shri Thanedar       T000488    Democrat   House    MI
# 95        Shri Thanedar       T000488    Democrat   House    MI
#
#             Asset Type                                             Issuer  \
# 0                Stock                   BJ's Wholesale Club Holdings Inc
# 1          Mutual-fund  JPMORGAN 100% US TREASURY SECURITIES MONEY MAR...
# 2          Mutual-fund  JPMORGAN 100% US TREASURY SECURITIES MONEY MAR...
# 3          Mutual-fund  JPMORGAN 100% US TREASURY SECURITIES MONEY MAR...
# 4   Municipal-security                                  US TREASURY BILLS
# ..                 ...                                                ...
# 91                 Etf                            SPDR GOLD MINISHARES TR
# 92  Municipal-security           GOVERNMENT NATIONAL MORTGAGE ASSOCIATION
# 93  Municipal-security           GOVERNMENT NATIONAL MORTGAGE ASSOCIATION
# 94               Stock                                       Alphabet Inc
# 95               Stock                                       Alphabet Inc
#
#    Ticker Issuer Country  Type       Date  Trade Size  Trade Price  \
# 0      BJ             us   Buy 2024-04-22       440.0        74.02
# 1   JTSXX           None   Buy 2024-04-24      8001.0         1.00
# 2   JTSXX           None   Buy 2024-04-09      8001.0         1.00
# 3   JTSXX           None   Buy 2024-04-01      8001.0         1.00
# 4    None           None   Buy 2024-04-24         NaN          NaN
# ..    ...            ...   ...        ...         ...          ...
# 91   GLDM             us  Sell 2024-04-25       174.0        46.25
# 92   None           None   Buy 2024-05-01         NaN          NaN
# 93   None           None   Buy 2024-05-01         NaN          NaN
# 94  GOOGL             us  Sell 2024-04-02        53.0       154.56
# 95  GOOGL             us  Sell 2024-04-02        53.0       154.56
#
#     Trade Value
# 0         32500
# 1          8000
# 2          8000
# 3          8000
# 4          8000
# ..          ...
# 91         8000
# 92        75000
# 93        32500
# 94         8000
# 95         8000
#
# [96 rows x 14 columns]

# %%
df_list = []
for num in range(1,100):
    url = f'https://bff.capitoltrades.com/trades?per_page=96&page={num}&pageSize=96'
    json_try = requests.get(url)
    dict_json = json.loads(json_try.text)
    
    
    name_lst = [index['politician']['firstName'] + " " + index['politician']['lastName'] for index in dict_json['data']]
    id_lst = [index['_politicianId'] for index in dict_json['data']]
    party_lst = [index['politician']['party'].capitalize() for index in dict_json['data']]
    chamber_lst = [index['politician']['chamber'].capitalize() for index in dict_json['data']]
    state_lst = [index['politician']['_stateId'].upper() for index in dict_json['data']]
    asset_type_lst = [index['asset']['assetType'].capitalize() for index in dict_json['data']]
    issuer_lst = [index['issuer']['issuerName'] for index in dict_json['data']]
    issuer_ticker_lst = []
    for index in dict_json['data']:
        if index['issuer']['issuerTicker'] is not None:
            issuer_ticker_lst.append(index['issuer']['issuerTicker'].split(':')[0])
        else:
            issuer_ticker_lst.append(None)

    issuer_country_lst = [index['issuer']['country'] for index in dict_json['data']]
    type_lst = [index['txType'].capitalize() for index in dict_json['data']]

    date_lst = []
    for index in dict_json['data']:
        date_object = datetime.strptime(index['txDate'], '%Y-%m-%d')
        date_lst.append(date_object)

    trade_size_lst = [index['size'] for index in dict_json['data']]
    trade_price = [index['price'] for index in dict_json['data']]
    trade_value = [index['value'] for index in dict_json['data']]


    
    df = pd.DataFrame({
        'Name': name_lst,
        'Politician Id': id_lst,
        'Party': party_lst,
        'Chamber': chamber_lst,
        'State': state_lst,
        'Asset Type': asset_type_lst,
        'Issuer': issuer_lst,
        'Ticker': issuer_ticker_lst,
        'Issuer Country': issuer_country_lst,
        'Type': type_lst,
        'Date': date_lst,
        'Trade Size': trade_size_lst,
        'Trade Price': trade_price,
        'Trade Value': trade_value
    }
    )
    df_list.append(df)
    
df = pd.concat(df_list, ignore_index=True)

    
df.to_csv('politician_dataset.csv')

# %%
df.head(25)
# Out:
#                Name Politician Id       Party Chamber State  \
# 0       Suzanne Lee       L000590    Democrat   House    NV
# 1        Laurel Lee       L000597  Republican   House    FL
# 2      Doris Matsui       M001163    Democrat   House    CA
# 3      Doris Matsui       M001163    Democrat   House    CA
# 4      Doris Matsui       M001163    Democrat   House    CA
# 5      Doris Matsui       M001163    Democrat   House    CA
# 6      Doris Matsui       M001163    Democrat   House    CA
# 7      Doris Matsui       M001163    Democrat   House    CA
# 8     Stephen Lynch       L000562    Democrat   House    MA
# 9    Jeffrey Duncan       D000615  Republican   House    SC
# 10   Jeffrey Duncan       D000615  Republican   House    SC
# 11      Gary Peters       P000595    Democrat  Senate    MI
# 12      Gary Peters       P000595    Democrat  Senate    MI
# 13      Gary Peters       P000595    Democrat  Senate    MI
# 14      Gary Peters       P000595    Democrat  Senate    MI
# 15    Kathy Manning       M001135    Democrat   House    NC
# 16    Kathy Manning       M001135    Democrat   House    NC
# 17    Kathy Manning       M001135    Democrat   House    NC
# 18  William Keating       K000375    Democrat   House    MA
# 19  William Keating       K000375    Democrat   House    MA
# 20  William Keating       K000375    Democrat   House    MA
# 21  William Keating       K000375    Democrat   House    MA
# 22  William Keating       K000375    Democrat   House    MA
# 23  William Keating       K000375    Democrat   House    MA
# 24  William Keating       K000375    Democrat   House    MA
#
#                     Asset Type                                    Issuer  \
# 0                        Stock                            RHEINMETALL AG
# 1               Corporate-bond                    TUHURA BIOSCIENCES INC
# 2           Municipal-security                          US TREASURY NOTE
# 3           Municipal-security                          US TREASURY NOTE
# 4           Municipal-security                          US TREASURY NOTE
# 5           Municipal-security                          US TREASURY NOTE
# 6           Municipal-security                          US TREASURY NOTE
# 7           Municipal-security                          US TREASURY NOTE
# 8                        Stock                        NVIDIA Corporation
# 9                        Stock                      Colgate-Palmolive Co
# 10                       Stock                                JD.com Inc
# 11                       Stock                            SOLVENTUM CORP
# 12                       Stock                Carnival Corporation & PLC
# 13                       Stock                          Schlumberger Ltd
# 14                       Stock    International Flavors & Fragrances Inc
# 15  Hedge-pvt-eq-funds-non-eif  SEVEN BRIDGES LONG SHORT EQUITY FUND LTD
# 16  Hedge-pvt-eq-funds-non-eif  SEVEN BRIDGES LONG SHORT EQUITY FUND LTD
# 17  Hedge-pvt-eq-funds-non-eif      SEVEN BRIDGES MULTI STRATEGY FUND LP
# 18                       Stock                             Accenture PLC
# 19                       Stock                                Airbnb Inc
# 20                       Stock                              Alphabet Inc
# 21                       Stock                            Amazon.com Inc
# 22                       Stock                              AutoZone Inc
# 23                       Stock                           CVS Health Corp
# 24                       Stock              Jacobs Engineering Group Inc
#
#    Ticker Issuer Country  Type       Date  Trade Size  Trade Price  \
# 0   RNMBY             de   Buy 2024-05-10        70.0      115.347
# 1    None           None   Buy 2024-05-06         NaN          NaN
# 2    None           None   Buy 2024-04-23         NaN          NaN
# 3    None           None   Buy 2024-04-23         NaN          NaN
# 4    None           None   Buy 2024-04-23         NaN          NaN
# 5    None           None   Buy 2024-04-23         NaN          NaN
# 6    None           None   Buy 2024-04-23         NaN          NaN
# 7    None           None   Buy 2024-04-23         NaN          NaN
# 8    NVDA             us   Buy 2024-05-22         9.0      949.500
# 9      CL             us  Sell 2023-08-25       109.0       73.830
# 10     JD             cn  Sell 2023-08-25       244.0       32.960
# 11   SOLV             us  Sell 2024-05-14         NaN          NaN
# 12    CCL             us  Sell 2024-05-14       552.0       14.520
# 13    SLB             us  Sell 2024-05-14       165.0       48.620
# 14    IFF             us  Sell 2024-05-14       337.0       96.630
# 15   None           None  Sell 2024-04-22         NaN          NaN
# 16   None           None  Sell 2024-05-03         NaN          NaN
# 17   None           None   Buy 2024-04-22         NaN          NaN
# 18    ACN             ie  Sell 2024-05-17        27.0      303.590
# 19   ABNB             us  Sell 2024-05-17        55.0      145.660
# 20  GOOGL             us  Sell 2024-05-17        46.0      176.060
# 21   AMZN             us   Buy 2024-05-17       177.0      184.700
# 22    AZO             us  Sell 2024-05-17         4.0     2917.500
# 23    CVS             us  Sell 2024-05-17       140.0       57.680
# 24      J             us  Sell 2024-05-17        59.0      136.440
#
#     Trade Value
# 0          8000
# 1        175000
# 2       1000000
# 3       1000000
# 4       1000000
# 5       1000000
# 6       1000000
# 7       1000000
# 8          8000
# 9          8000
# 10         8000
# 11         8000
# 12         8000
# 13         8000
# 14        32500
# 15       175000
# 16       750000
# 17       175000
# 18         8000
# 19         8000
# 20         8000
# 21        32500
# 22         8000
# 23         8000
# 24         8000

# %%
df[df['Ticker'] == 'AAPL'].sort_values(by='Trade Value', ascending=False)
# Out:
#                         Name Politician Id       Party Chamber State  \
# 9435            Nancy Pelosi       P000197    Democrat   House    CA
# 2513       Thomas Tuberville       T000278  Republican  Senate    AL
# 1351          Stock  Apple Inc   AAPL             us  Sell 2024-03-25
# 1547          Stock  Apple Inc   AAPL             us  Sell 2024-03-22
# 1548          Stock  Apple Inc   AAPL             us  Sell 2024-03-15
# 1610          Stock  Apple Inc   AAPL             us  Sell 2024-03-07
# 2437          Stock  Apple Inc   AAPL             us  Sell 2024-01-18
# 2524  Stock-options  Apple Inc   AAPL             us   Buy 2024-01-10
# 2576          Stock  Apple Inc   AAPL             us  Sell 2024-01-23
# 2577          Stock  Apple Inc   AAPL             us  Sell 2024-01-23
# 2737          Stock  Apple Inc   AAPL             us   Buy 2024-01-10
# 3136          Stock  Apple Inc   AAPL             us  Sell 2024-01-19
# 3137          Stock  Apple Inc   AAPL             us  Sell 2024-01-19
# 3258          Stock  Apple Inc   AAPL             us  Sell 2023-12-14
# 3281          Stock  Apple Inc   AAPL             us  Sell 2023-12-14
# 3366          Stock  Apple Inc   AAPL             us  Sell 2023-12-19
# 3785          Stock  Apple Inc   AAPL             us  Sell 2023-12-04
# 3138          Stock  Apple Inc   AAPL             us   Buy 2023-12-22
# 2194          Stock  Apple Inc   AAPL             us   Buy 2024-02-29
#
#       Trade Size  Trade Price  Trade Value
# 9435      5000.0        80.00       375000
# 2513      1959.0       191.56       375000
# 3105       405.0       185.64        75000
# 6138       432.0       174.21        75000
# 293        193.0       168.84        32500
# 7071       171.0       191.17        32500
# 5397       190.0       171.96        32500
# 292        193.0       168.84        32500
# 6049       184.0       177.56        32500
# 6096       182.0       179.36        32500
# 3135       171.0       191.56        32500
# 2831       175.0       186.19        32500
# 2578       167.0       195.18        32500
# 6744       184.0       177.23        32500
# 6782       182.0       178.85        32500
# 2526       177.0       184.25        32500
# 5166       183.0       178.39        32500
# 5396       188.0       173.44        32500
# 2208       168.0       194.17        32500
# 1481       182.0       178.67        32500
# 9038       172.0       189.59        32500
# 667        195.0       166.90        32500
# 973        191.0       171.13        32500
# 1214       188.0       173.23        32500
# 2207       168.0       194.17        32500
# 8724        44.0       186.68         8000
# 8664        44.0       183.95         8000
# 8725        43.0       189.59         8000
# 9309        44.0       187.00         8000
# 7373        42.0       193.73         8000
# 7333        45.0       178.85         8000
# 5991        47.0       171.96         8000
# 5728        47.0       170.69         8000
# 5643        47.0       172.40         8000
# 5566        47.0       173.97         8000
# 9308        44.0       184.92         8000
# 6845        46.0       177.23         8000
# 260         42.0       192.35         8000
# 4822        47.0       173.75         8000
# 4660        48.0       170.29         8000
# 445         48.0       166.90         8000
# 449         48.0       169.67         8000
# 635         48.0       169.30         8000
# 1351        47.0       170.85         8000
# 1547        47.0       172.28         8000
# 1548        47.0       172.62         8000
# 1610        48.0       169.00         8000
# 2437        43.0       188.63         8000
# 2524         NaN          NaN         8000
# 2576        42.0       195.18         8000
# 2577        42.0       195.18         8000
# 2737        44.0       186.19         8000
# 3136        43.0       191.56         8000
# 3137        43.0       191.56         8000
# 3258        41.0       198.11         8000
# 3281        41.0       198.11         8000
# 3366        42.0       196.94         8000
# 3785        43.0       189.43         8000
# 3138        42.0       193.60         8000
# 2194         2.0       180.75          360

# %%
df.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[404], line 1
# ----> 1 df.types
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'types'
