# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
## 115 - 2017-2019
## 116 - 2019-2021
## 117 - 2021 - 2023
## 118 - 2023 - 2025

## s - senate 
## hr - house of reps 
## hjres - subset of hr 
## sjres - subset of senate

legislation_data = requests.get(f"https://www.congress.gov/advanced-search/legislation?congresses%5B0%5D=118&congresses%5B1%5D=117&congresses%5B2%5D=116&congresses%5B3%5D=115&legislationNumbers=&restrictionType=field&restrictionFields%5B0%5D=allBillTitles&restrictionFields%5B1%5D=summary&summaryField=billSummary&enterTerms=&wordVariants=true&legislationTypes%5B0%5D=hr&legislationTypes%5B1%5D=hjres&legislationTypes%5B2%5D=s&legislationTypes%5B3%5D=sjres&becamelaw=true&actionTerms=&legislativeActionWordVariants=true&actionDateBoxCount=2&actionText=&actionText2=&dateOfActionToggle=multi&legislativeAction=156&sponsorState=One&member=&sponsorTypes%5B0%5D=sponsor&sponsorTypeBool=OR&dateOfSponsorshipOperator=equal&dateOfSponsorshipStartDate=&dateOfSponsorshipEndDate=&dateOfSponsorshipIsOptions=yesterday&committeeActivity%5B0%5D=0&committeeActivity%5B1%5D=3&committeeActivity%5B2%5D=11&committeeActivity%5B3%5D=12&committeeActivity%5B4%5D=4&committeeActivity%5B5%5D=2&committeeActivity%5B6%5D=5&committeeActivity%5B7%5D=9&satellite=%5B%5D&search=&submitted=Submitted")
soup = BeautifulSoup(legislation_data.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all(class_="result-title")
# Out:
# []
