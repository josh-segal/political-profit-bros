# %%
import pandas as pd 
from datetime import datetime

# %%
import chardet

# Replace 'your_file.txt' with the path to your text file
# with open('bills.csv', 'rb') as f:
#     print(f)
#     result = chardet.detect(f.read())
#     print(result['encoding'])


# df = pd.read_csv('bills.csv',sep=';')
df = pd.read_csv('bills3.csv', index_col=0)
df
# Out:
#                                       Congress  \
# Legislation Number
# H.R. 8289           118th Congress (2023-2024)
# H.R. 7888           118th Congress (2023-2024)
# H.R. 7463           118th Congress (2023-2024)
# H.R. 7454           118th Congress (2023-2024)
# H.R. 6503           118th Congress (2023-2024)
# ...                                        ...
# S.J.Res. 36         115th Congress (2017-2018)
# S.J.Res. 35         115th Congress (2017-2018)
# S.J.Res. 34         115th Congress (2017-2018)
# S.J.Res. 30         115th Congress (2017-2018)
# S.J.Res. 1          115th Congress (2017-2018)
#
#                                                                 Title  \
# Legislation Number
# H.R. 8289           Airport and Airway Extension Act of 2024, Part II
# H.R. 7888             Reforming Intelligence and Securing America Act
# H.R. 7463           Extension of Continuing Appropriations and Oth...
# H.R. 7454                    Airport and Airway Extension Act of 2024
# ...

# %%
df = df.iloc[:, :6]
df
# Out:
#                                       Congress  \
# Legislation Number
# H.R. 8289           118th Congress (2023-2024)
# H.R. 7888           118th Congress (2023-2024)
# H.R. 7463           118th Congress (2023-2024)
# H.R. 7454           118th Congress (2023-2024)
# H.R. 6503           118th Congress (2023-2024)
# ...                                        ...
# S.J.Res. 36         115th Congress (2017-2018)
# S.J.Res. 35         115th Congress (2017-2018)
# S.J.Res. 34         115th Congress (2017-2018)
# S.J.Res. 30         115th Congress (2017-2018)
# S.J.Res. 1          115th Congress (2017-2018)
#
#                                                                 Title  \
# Legislation Number
# H.R. 8289           Airport and Airway Extension Act of 2024, Part II
# H.R. 7888             Reforming Intelligence and Securing America Act
# H.R. 7463           Extension of Continuing Appropriations and Oth...
# H.R. 7454                    Airport and Airway Extension Act of 2024
# ...

# %%
#df["Date of Introduction"].astype('datetime64[ns]')
pd.to_datetime(df['Date of Introduction'], format='%y%m%d')
df
# Out:
#                                       Congress  \
# Legislation Number
# H.R. 8289           118th Congress (2023-2024)
# H.R. 7888           118th Congress (2023-2024)
# H.R. 7463           118th Congress (2023-2024)
# H.R. 7454           118th Congress (2023-2024)
# H.R. 6503           118th Congress (2023-2024)
# ...                                        ...
# S.J.Res. 36         115th Congress (2017-2018)
# S.J.Res. 35         115th Congress (2017-2018)
# S.J.Res. 34         115th Congress (2017-2018)
# S.J.Res. 30         115th Congress (2017-2018)
# S.J.Res. 1          115th Congress (2017-2018)
#
#                                                                 Title  \
# Legislation Number
# H.R. 8289           Airport and Airway Extension Act of 2024, Part II
# H.R. 7888             Reforming Intelligence and Securing America Act
# H.R. 7463           Extension of Continuing Appropriations and Oth...
# H.R. 7454                    Airport and Airway Extension Act of 2024
# ...
